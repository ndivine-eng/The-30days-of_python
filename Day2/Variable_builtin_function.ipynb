# %%
# Exercises: Level 1
# 'Day 2: 30 Days of python programming'
First_name="Divine"
Last_name="Nubuhoro"
Full_name="Nubuhoro Divine"
Country="Rwanda"
City="kamembe"
Age=22
year=2025

# Declare a variable is_married and assign a value to it
is_married = False  
#Declare a variable is_true and assign a value to it
is_true = True 
#Declare a variable is_light_on and assign a value to it
is_light_on = True  
#Declare multiple variable on one line
is_sunny, is_raining, is_windy = True, False, True  


#checking the data type
print( "First name's data type is in:", type( First_name))
print("Year is in :", type(year))
print(type(is_married))
print(type(is_sunny))

#Compare the length of your first name and your last name
print("Length of First name:", len(First_name))
print("Length of second name:", len(Last_name))
print("Are length equals?", len(First_name) == len(Last_name))

#Declare 5 as num_one and 4 as num_two
num_1=5
num_2=4

#Add num_one and num_two and assign the value to a variable total
total= num_1+ num_2
diff=num_1 - num_2 #Subtract num_two from num_one and assign the value to a variable diff
mult= num_2 * num_1 #Multiply num_two and num_one and assign the value to a variable product
div = num_1/num_2 #Divide num_one by num_two and assign the value to a variable division
Remainder = num_1% num_2 #Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
exp= num_1 ** num_2 #Calculate num_one to the power of num_two and assign the value to a variable exp
floor_div= num_1 // num_2#Find floor division of num_one by num_two and assign the value to a variable floor_division

# print the results 
print("Total:", total)
print("Difference:", diff)
print("Product:", mult)
print("Division:", div)
print("Remainder:", Remainder)
print("Exponentiation:", exp)
print("Floor Division:", floor_div)

#The radius of a circle is 30 meters.

Radius = 30 
pi= 3.14
Area = 2 * (Radius ** 2) #Calculate the area of a circle and assign the value to a variable name of area_of_circle
Circumstance = 2 * pi *Radius #Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
print("Area of the circle:", Area)
print("Circumstance of circle:", Circumstance)

#Take radius as user input and calculate the area.
radius_input= float(input("Enter the radius of circle: "))
Area_of_circle = pi* (radius_input ** 2)
print("Area of circle (user input):", Area_of_circle)
#Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names

first_name_input = input("Enter your first name: ")
last_name_input = input("Enter your last name: ")
country_input = input("Enter your country: ")
age_input = int(input("Enter your age: "))

print("User Details:", first_name_input, last_name_input, country_input, age_input)
# Out:
# First name's data type is in: <class 'str'>
# Year is in : <class 'int'>
# <class 'bool'>
# <class 'bool'>
# Length of First name: 6
# Length of second name: 8
# Are length equals? False
# Total: 9
# Difference: 1
# Product: 20
# Division: 1.25
# Remainder: 1
# Exponentiation: 625
# Floor Division: 1
# Area of the circle: 1800
# Circumstance of circle: 188.4
# Area of circle (user input): 13266.5
# User Details: uwera Ange Rwanda 20
